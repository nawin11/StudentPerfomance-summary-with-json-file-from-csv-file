# %%
import pandas as pd
df = pd.read_csv ('StudentsPerformance.csv')
df.to_json ('StudentsPerformance.json')
import json
f = open('StudentsPerformance.json')
StudentsPerformance = json.load(f)

StudentsPerformance
# Out:
# {'gender': {'0': 'female',
#   '1': 'female',
#   '2': 'female',
#   '3': 'male',
#   '4': 'male',
#   '5': 'female',
#   '6': 'female',
#   '7': 'male',
#   '8': 'male',
#   '9': 'female',
#   '10': 'male',
#   '11': 'male',
#   '12': 'female',
#   '13': 'male',
#   '14': 'female',
#   '15': 'female',
#   '16': 'male',
#   '17': 'female',
#   '18': 'male',
#   '19': 'female',
#   '20': 'male',
#   '21': 'female',
#   '22': 'male',
#   '23': 'female',
#   '24': 'male',
#   '25': 'male',
#   '26': 'male',
#   '27': 'female',
#   '28': 'male',
#   '29': 'female',
#   '30': 'female',
#   '31': 'female',
#   '32': 'female',
#   '33': 'male',
#   '34': 'male',
#   '35': 'male',
#   '36': 'female',
#   '37': 'female',
#   '38': 'female',
#   '39': 'male',
#   '40': 'male',
#   '41': 'female',
#   '42': 'female',
#   '43': 'male',
#   '44': 'female',
#   '45': 'male',
#   '46': 'female',
#   '47': 'female',
#   '48': 'female',
#   '49': 'male',
#   '50': 'male',
#   '51': 'male',
# ...
